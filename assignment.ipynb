# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("Used_Bikes.csv")
df
# print(df)
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
# •	1     Find out the no. of record for each ownership bike.
# •	2     Find out the no. of bikes, who has “First Owner” and age <=5.
# •	3     Find out the bikes at Jaipur location, price under in 60K.
# •	4 Find out the bikes of KTM brand who has minimum and maximum price.

# %%
# max_ktm =  df[(df["brand"] == "KTM") & (df["price"]== df['price'].min())]
ktm = df[(df["price"]== df['price'].min()]

# max_ktm
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [33], in <cell line: 1>()
# ----> 1 max_ktm =  df["price"]== df[(df["brand"] == "KTM").df['price'].min()]
#       2 # ktm = df[df["price"]== df['price'].min()]
#       3 # ktm
#       4 max_ktm
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'df'

# %%
#2

bikes_fetch = df[(df['owner']== "First Owner") & (df['city']== 'Jaipur')& (df["age" ]<= 5)]
bikes_fetch
# Out:
#                                       bike_name      price    city  \
# 47                   Mahindra Centuro NXT 110cc    28000.0  Jaipur
# 166                 Royal Enfield Classic 350cc   123600.0  Jaipur
# 617                      Suzuki Hayabusa 1300cc  1260000.0  Jaipur
# 784                      Bajaj Pulsar RS200 ABS   100000.0  Jaipur
# 972                           Yamaha FZ25 250cc   105000.0  Jaipur
# ...                                         ...        ...     ...
# 8074                       TVS Apache RTR 180cc    65000.0  Jaipur
# 8461  Royal Enfield Classic Squadron Blue 500cc   160000.0  Jaipur
# 8921                         Bajaj Pulsar RS200   110000.0  Jaipur
# 9187             Harley-Davidson Street 750 ABS   520000.0  Jaipur
# 9259                     Yamaha Saluto RX 110cc    37000.0  Jaipur
#
#       kms_driven        owner  age   power            brand
# 47       45000.0  First Owner  2.0   110.0         Mahindra
# ...

# %%
#

bikes_fetch = df[(df["brand"] == "KTM") & (df['price'].max())]
bikes_fetch
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:301, in na_logical_op(x, y, op)
#     292 try:
#     293     # For exposition, write:
#     294     #  yarr = isinstance(y, np.ndarray)
#    (...)
#     299     # Then Cases where this goes through without raising include:
#     300     #  (xint or xbool) and (yint or bool)
# --> 301     result = op(x, y)
#     302 except TypeError:
#
# TypeError: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:315, in na_logical_op(x, y, op)
#     314 try:
# ...

# %%
CNT = df['price'].max()
CNT
# Out:
# 1900000.0

# %%
#1
# RAND

CNT = df['owner'].value_counts()
CNT
# Out:
# First Owner             29964
# Second Owner             2564
# Third Owner               108
# Fourth Owner Or More       12
# Name: owner, dtype: int64

# %%
#3
bikes_fetch = df[(df["brand"] == "TVS") & (df["city"] == "Jaipur") & (df["price" ]<= 60000)]
bikes_fetch
# Out:
#                      bike_name    price    city  kms_driven         owner  \
# 2302      TVS Apache RTR 160cc  19542.0  Jaipur     56592.0   First Owner
# 2395      TVS Apache RTR 160cc  19542.0  Jaipur     56592.0   First Owner
# 3364  TVS Star City Plus 110cc  30000.0  Jaipur     27000.0   First Owner
# 3904      TVS Apache RTR 160cc  51000.0  Jaipur     18314.0   First Owner
# 3907      TVS Apache RTR 160cc  47000.0  Jaipur     26000.0   First Owner
# 3920       TVS Star City 110cc  26500.0  Jaipur      2342.0   First Owner
# 3922       TVS Star City 110cc  26000.0  Jaipur     24000.0   First Owner
# 4063           TVS Sport 100cc  33000.0  Jaipur     18677.0   First Owner
# 4181      TVS Apache RTR 160cc  51000.0  Jaipur     18314.0   First Owner
# 4607           TVS Sport 100cc  23000.0  Jaipur     28895.0   First Owner
# 4851      TVS Apache RTR 160cc  45000.0  Jaipur     20431.0   First Owner
# 4886  TVS Apache RTR 180cc ABS  59900.0  Jaipur     32000.0   First Owner
# ...
